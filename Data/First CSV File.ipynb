# %%
import sqlite3
import csv

def sqlite_to_csv(db_file, output_folder):
    # Connect to the SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Get the list of all tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    for table in tables:
        table_name = table[0]
        print(f"Exporting table: {table_name}")

        # Query all rows from the table
        cursor.execute(f"SELECT * FROM {table_name}")
        rows = cursor.fetchall()

        # Get column headers
        column_names = [description[0] for description in cursor.description]

        # Write the table to a CSV file
        with open(f"{output_folder}/{table_name}.csv", mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(column_names)  # Write the header row
            writer.writerows(rows)         # Write the data rows

    # Close the database connection
    conn.close()

# Example usage
sqlite_to_csv('your_database.db', 'output_folder')

# %%
import sqlite3
import csv
import os

def sqlite_to_csv(db_file, output_folder):
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Connect to the SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Get the list of all tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    # Debug: Print out the list of tables
    print(f"Tables found: {tables}")

    for table in tables:
        table_name = table[0]
        print(f"Exporting table: {table_name}")

        # Query all rows from the table
        cursor.execute(f"SELECT * FROM {table_name}")
        rows = cursor.fetchall()

        # Get column headers
        column_names = [description[0] for description in cursor.description]

        # Debug: Print column names and number of rows
        print(f"Column names: {column_names}")
        print(f"Rows count: {len(rows)}")

        # Write the table to a CSV file
        try:
            with open(f"{output_folder}/{table_name}.csv", mode='w', newline='', encoding='utf-8') as file:
                writer = csv.writer(file)
                writer.writerow(column_names)  # Write the header row
                writer.writerows(rows)         # Write the data rows
            print(f"File {table_name}.csv written successfully!")
        except Exception as e:
            print(f"Error writing {table_name}.csv: {e}")

    # Close the database connection
    conn.close()

# Example usage
sqlite_to_csv('FPA_FOD_20170508.sqlite', 'output_folder')
# Out:
# Tables found: []

# %%
import sqlite3
import csv
import os

def sqlite_to_csv(db_file, output_folder):
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Connect to the SQLite database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Get the list of all tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    print(f"Tables found: {tables}")

    if not tables:
        print("No tables found in the database. The database might be empty or corrupted.")
        conn.close()
        return

    for table in tables:
        table_name = table[0]
        print(f"Exporting table: {table_name}")

        # Query all rows from the table
        cursor.execute(f"SELECT * FROM {table_name}")
        rows = cursor.fetchall()

        # Get column headers
        column_names = [description[0] for description in cursor.description]

        # Write the table to a CSV file
        try:
            with open(f"{output_folder}/{table_name}.csv", mode='w', newline='', encoding='utf-8') as file:
                writer = csv.writer(file)
                writer.writerow(column_names)  # Write the header row
                writer.writerows(rows)         # Write the data rows
            print(f"File {table_name}.csv written successfully!")
        except Exception as e:
            print(f"Error writing {table_name}.csv: {e}")

    # Close the database connection
    conn.close()

sqlite_to_csv('FPA_FOD_20210617.sqlite', 'output_folder')
# Out:
# Tables found: [('NWCG_UnitIDActive_20200123',), ('Fires',)]
# Exporting table: NWCG_UnitIDActive_20200123
# File NWCG_UnitIDActive_20200123.csv written successfully!
# Exporting table: Fires
# File Fires.csv written successfully!

# %%
sqlite_to_csv('FPA_FOD_20221-14.sqlite', 'output_folder')
# Out:
# Tables found: []
# No tables found in the database. The database might be empty or corrupted.

# %%
import sqlite3

db_file = 'FPA_FOD_20210617.sqlite'
conn = None # Initialize conn to None
try:
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    if tables:
        print(f"Tables found in the database '{db_file}':")
        for table in tables:
            print(f"- {table[0]}")
    else:
        print(f"No tables found in the database '{db_file}'.")

except sqlite3.Error as e:
    print(f"SQLite error: {e}")
finally:
    if conn:
        conn.close()
# Out:
# Tables found in the database 'FPA_FOD_20210617.sqlite':
# - NWCG_UnitIDActive_20200123
# - Fires
